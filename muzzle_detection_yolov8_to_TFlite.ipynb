# %% [markdown]
# <a href="https://colab.research.google.com/github/s4ki3f/Blur-and-Clear-Classification/blob/master/muzzle_detection_yolov8_to_TFlite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.72 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.2/78.2 GB disk)

# %%
# Run inference on an image with YOLOv8n
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/zidane.jpg'
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 83.0MB/s]
# Ultralytics YOLOv8.0.72 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100% 165k/165k [00:00<00:00, 6.93MB/s]
# image 1/1 /content/zidane.jpg: 384x640 2 persons, 1 tie, 66.3ms
# Speed: 0.6ms preprocess, 66.3ms inference, 278.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="LBLyC3MJnNhkwTi9uIAR")
project = rf.workspace("null-tttt4").project("muzzle-detector")
dataset = project.version(1).download("yolov8")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 6.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.3 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9676 sha256=7b18def3350535371f787cb2b347721a2cc39ae215d5ad6f1fa8bbde9707bb93
#   Stored in directory: /root/.cache/pip/wheels/04/5f/3e/46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
# ...

# %%
# !yolo train model=yolov8n.pt data=/content/muzzle-detector-1/data.yaml epochs=3 imgsz=640
# Out:
# Ultralytics YOLOv8.0.72 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo train model=yolov8n.pt data=/content/muzzle-detector-1/data.yaml epochs=500 imgsz=640
# Out:
# Ultralytics YOLOv8.0.72 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo train model=yolov8n.pt data=/content/muzzle-detector-1/data.yaml epochs=500 imgsz=640 patience=0
# Out:
# Ultralytics YOLOv8.0.72 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo export model=yolov8n.pt format=tflite
# Out:
# Ultralytics YOLOv8.0.72 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from yolov8n.pt with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.12.0...
#
# ONNX: starting export with onnx 1.13.1 opset 17...
# ============= Diagnostic Run torch.onnx.export version 2.0.0+cu118 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# ONNX: simplifying with onnxsim 0.4.19...
# ONNX: export success ✅ 3.3s, saved as yolov8n.onnx (12.2 MB)
#
# TensorFlow SavedModel: running 'onnx2tf -i yolov8n.onnx -o yolov8n_saved_model -nuo --non_verbose'
# 2023-04-10 20:44:45.281013: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# !yolo predict task=detect model=yolov8n_saved_model/yolov8n_float32.tflite imgsz=640 source=/content/muzzle-detector-1/test/images/20221003_114826_jpg.rf.5f76ee4e1a08c63a0ae260d281aae012.jpg
# Out:
# Ultralytics YOLOv8.0.72 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Loading yolov8n_saved_model/yolov8n_float32.tflite for TensorFlow Lite inference...
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
#
# image 1/1 /content/muzzle-detector-1/test/images/20221003_114826_jpg.rf.5f76ee4e1a08c63a0ae260d281aae012.jpg: 640x640 1 dog, 328.4ms
# Speed: 33.5ms preprocess, 328.4ms inference, 137.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2

# %%
# !yolo export model=/content/runs/detect/train2/weights/best.pt format=tflite
# Out:
# Ultralytics YOLOv8.0.72 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 168 layers, 3007208 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from /content/runs/detect/train2/weights/best.pt with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 12, 8400) (6.0 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.12.0...
#
# ONNX: starting export with onnx 1.13.1 opset 17...
# ============= Diagnostic Run torch.onnx.export version 2.0.0+cu118 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# ONNX: simplifying with onnxsim 0.4.19...
# ONNX: export success ✅ 2.5s, saved as /content/runs/detect/train2/weights/best.onnx (11.6 MB)
#
# TensorFlow SavedModel: running 'onnx2tf -i /content/runs/detect/train2/weights/best.onnx -o /content/runs/detect/train2/weights/best_saved_model -nuo --non_verbose'
# ...

# %%
# !yolo predict task=detect model=/content/runs/detect/train2/weights/best_saved_model/best_float32.tflite imgsz=640 source=/content/muzzle-detector-1/test/images/20221003_114826_jpg.rf.5f76ee4e1a08c63a0ae260d281aae012.jpg
# Out:
# Ultralytics YOLOv8.0.72 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Loading /content/runs/detect/train2/weights/best_saved_model/best_float32.tflite for TensorFlow Lite inference...
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
#
# image 1/1 /content/muzzle-detector-1/test/images/20221003_114826_jpg.rf.5f76ee4e1a08c63a0ae260d281aae012.jpg: 640x640 1 Bullry, 1 cow-muzzle, 345.7ms
# Speed: 44.9ms preprocess, 345.7ms inference, 157.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict3

# %%
# !yolo export model=/content/runs/detect/train3/weights/best.pt format=tflite
# Out:
# Ultralytics YOLOv8.0.72 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 168 layers, 3007208 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from /content/runs/detect/train3/weights/best.pt with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 12, 8400) (6.0 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.12.0...
#
# ONNX: starting export with onnx 1.13.1 opset 17...
# ============= Diagnostic Run torch.onnx.export version 2.0.0+cu118 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# ONNX: simplifying with onnxsim 0.4.19...
# ONNX: export success ✅ 2.4s, saved as /content/runs/detect/train3/weights/best.onnx (11.6 MB)
#
# TensorFlow SavedModel: running 'onnx2tf -i /content/runs/detect/train3/weights/best.onnx -o /content/runs/detect/train3/weights/best_saved_model -nuo --non_verbose'
# ...

# %%
# !yolo predict task=detect model=/content/runs/detect/train3/weights/best_saved_model/best_float32.tflite imgsz=640 source=/content/muzzle-detector-1/test/images/20221003_114826_jpg.rf.5f76ee4e1a08c63a0ae260d281aae012.jpg
# Out:
# Ultralytics YOLOv8.0.72 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Loading /content/runs/detect/train3/weights/best_saved_model/best_float32.tflite for TensorFlow Lite inference...
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
#
# image 1/1 /content/muzzle-detector-1/test/images/20221003_114826_jpg.rf.5f76ee4e1a08c63a0ae260d281aae012.jpg: 640x640 1 Bullry, 256.0ms
# Speed: 32.1ms preprocess, 256.0ms inference, 133.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict4
